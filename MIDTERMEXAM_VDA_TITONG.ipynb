# %% [markdown]
# <a href="https://colab.research.google.com/github/LeeIvanTitong/VDA-CpE-031-CpE21S4/blob/main/MIDTERMEXAM_VDA_TITONG.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Instructions:
#
# Download the Indicators of Heart Disease (2022 UPDATE)Links to an external site.dataset from Kaggle, and load it into your Google Colab.
# Familiarize yourself with the variables and observations using Pandas.
# Then, formulate two questions based on your understanding of the dataset.
# After which, you will need to answer these questions by producing a data visualization of your choice using Matplotlib.
# Write your observation for each visualization, then take a screenshot of your work (one screenshot per visualization)  to be uploaded as your final output.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
#2. Read the CSV File

data = pd.read_csv('/content/heart_2020_cleaned.csv')

data.head(10)
# Out:
#   HeartDisease    BMI Smoking AlcoholDrinking Stroke  PhysicalHealth  \
# 0           No  16.60     Yes              No     No             3.0
# 1           No  20.34      No              No    Yes             0.0
# 2           No  26.58     Yes              No     No            20.0
# 3           No  24.21      No              No     No             0.0
# 4           No  23.71      No              No     No            28.0
# 5          Yes  28.87     Yes              No     No             6.0
# 6           No  21.63      No              No     No            15.0
# 7           No  31.64     Yes              No     No             5.0
# 8           No  26.45      No              No     No             0.0
# 9           No  40.69      No              No     No             0.0
#
#    MentalHealth DiffWalking     Sex  AgeCategory   Race  \
# 0          30.0          No  Female        55-59  White
# 1           0.0          No  Female  80 or older  White
# ...

# %% [markdown]
# # 1).Physical Activity and Heart Disease Across Age Categories?

# %%
age_physical_activity = data.groupby(['AgeCategory', 'PhysicalActivity'])['HeartDisease'].mean().unstack()


age_physical_activity.plot(kind='bar', stacked=True, figsize=(10,6), color=['lightblue', 'lightcoral'])
plt.title('Heart Disease and Physical Activity Across Age Categories')
plt.xlabel('Age Category')
plt.ylabel('Proportion with Heart Disease')
plt.xticks(rotation=45)
plt.legend(title='Physical Activity', labels=['Inactive', 'Active'])
plt.show()

# %% [markdown]
# OBSERVATION: The stacked bar chart shows how physical activity correlates with heart disease across different age categories and can easi

# %% [markdown]
# # 2).Does smoking affect the likelihood of having heart disease?

# %%
data = pd.read_csv('/content/heart_2020_cleaned.csv')

data['HeartDisease'] = (data['HeartDisease'] == 'Yes').astype(int)
smoking_heart_disease = data.groupby('Smoking')['HeartDisease'].mean()
smoking_heart_disease.plot(kind='bar', figsize=(8,6), color=['lightblue', 'lightcoral'])

plt.title('Heart Disease by Smoking Status')
plt.xlabel('Smoking Status')
plt.ylabel('Proportion of Heart Disease')
plt.show()

# %% [markdown]
# OBSERVATION: The bar chart compares the proportion of individuals with heart disease in two groups smokers and nonsmokers
